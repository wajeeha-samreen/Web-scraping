# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonuthahreen/Web-Scrapping/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url="https://www.wscubetech.com/"
r=requests.get(url)
print(r.status_code)
# Out:
# 200

# %% [markdown]
# Resource:https://developer.mozilla.org/en-US/docs/Web/HTTP/Status
#
# to know more about status code
#
# **HTTP response status codes**
#
# HTTP response status codes indicate whether a specific HTTP request has been
# successfully completed.
#
# Responses are grouped in five classes:
#
# Informational responses (100 – 199)
#
# Successful responses (200 – 299)
#
# Redirection messages (300 – 399)
#
# Client error responses (400 – 499)
#
# Server error responses (500 – 599)

# %%
#to get the total HTML of particular page
url="https://www.wscubetech.com/"
r=requests.get(url)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <!-- Google Tag Manager -->
#     <script>
#     (function(w, d, s, l, i) {
#         w[l] = w[l] || [];
#         w[l].push({
#             'gtm.start': new Date().getTime(),
#             event: 'gtm.js'
#         });
#         var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s),
#             dl = l != 'dataLayer' ? '&l=' + l : '';
#         j.async = true;
#         j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#         f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-52JC74P');
#     </script>
#     <!-- End Google Tag Manager -->
#
#     <!-- Google tag (gtag.js) -->
#     <!-- <script async src="https://www.googletagmanager.com/gtag/js?id=AW-10998233603"></script>
#     <script>
#     window.dataLayer = window.dataLayer || [];
#
#     function gtag() {
#         dataLayer.push(arguments);
#     }
#     gtag('js', new Date());
#
# ...

# %%
from bs4 import BeautifulSoup

# %%
#to get the total HTML of particular page
url="https://www.wscubetech.com/"
r=requests.get(url)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <!-- Google Tag Manager -->
#     <script>
#     (function(w, d, s, l, i) {
#         w[l] = w[l] || [];
#         w[l].push({
#             'gtm.start': new Date().getTime(),
#             event: 'gtm.js'
#         });
#         var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s),
#             dl = l != 'dataLayer' ? '&l=' + l : '';
#         j.async = true;
#         j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#         f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-52JC74P');
#     </script>
#     <!-- End Google Tag Manager -->
#
#     <!-- Google tag (gtag.js) -->
#     <!-- <script async src="https://www.googletagmanager.com/gtag/js?id=AW-10998233603"></script>
#     <script>
#     window.dataLayer = window.dataLayer || [];
#
#     function gtag() {
#         dataLayer.push(arguments);
#     }
#     gtag('js', new Date());
#
# ...

# %% [markdown]
# **To obtain HTML of any website using BeautifulSoup**

# %%
url="https://www.wscubetech.com/"
r=requests.get(url)
soup =BeautifulSoup(r.text,"lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!-- Google Tag Manager -->
# <script>
#     (function(w, d, s, l, i) {
#         w[l] = w[l] || [];
#         w[l].push({
#             'gtm.start': new Date().getTime(),
#             event: 'gtm.js'
#         });
#         var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s),
#             dl = l != 'dataLayer' ? '&l=' + l : '';
#         j.async = true;
#         j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#         f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-52JC74P');
#     </script>
# <!-- End Google Tag Manager -->
# <!-- Google tag (gtag.js) -->
# <!-- <script async src="https://www.googletagmanager.com/gtag/js?id=AW-10998233603"></script>
#     <script>
#     window.dataLayer = window.dataLayer || [];
#
#     function gtag() {
#         dataLayer.push(arguments);
#     }
#     gtag('js', new Date());
#
#     gtag('config', 'AW-10998233603');
# ...

# %%
url="https://webscraper.io/test-sites/e-commerce/allinone"
r=requests.get(url)
print(r.status_code)
# Out:
# 200

# %% [markdown]
# **Tags in HTML**

# %%
url="https://webscraper.io/test-sites/e-commerce/allinone"
r=requests.get(url)
Soup=BeautifulSoup(r.text,"lxml")
##print(soup) this is used for total html code
print(soup.div)##this div is used for displaying tags of HTML
# Out:
# <div class="container-fluid">
# <a class="navbar-brand me-xl-4 me-3" href="https://www.wscubetech.com" title="WsCube Tech">
# <img alt="Wscube tech logo" height="60" src="https://www.wscubetech.com/images/wscube-tech-logo.svg" width="140"/>
# </a>
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler border-0 p-0 shadow-none" data-bs-target="#navbarSupportedContent" data-bs-toggle="collapse" type="button">
# <img alt="Menu" class="img-fluid open-icon" height="35" src="https://www.wscubetech.com/images/menubar-icon.svg" width="35"/>
# <img alt="Menu" class="img-fluid close-icon d-none" height="25" src="https://www.wscubetech.com/images/close-menu.svg" width="25"/>
# </button>
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav me-auto mb-2 mb-lg-0 ws-main-menu">
# <li class="nav-item mx-lg-1">
# ...

# %% [markdown]
# **Attributes in HTML**

# %%
#to get ul tags

url="https://www.wscubetech.com/"
r=requests.get(url)
soup =BeautifulSoup(r.text,"lxml")
print(soup.div.ul)
#a tags print(soup.div.a)
# p tags print(soup.div.p)
# Out:
# <ul class="navbar-nav me-auto mb-2 mb-lg-0 ws-main-menu">
# <li class="nav-item mx-lg-1">
# <!-- <a class="nav-link cursor-pointer label-color-1 fs-15" title="Classroom Training">Classroom
#                                 Training <img src="https://www.wscubetech.com/images/up-arrow.svg" alt="arrow" /></a> -->
# <a class="nav-link cursor-pointer label-color-1 fs-15" title="Offline">Offline
#                                 <img alt="arrow" src="https://www.wscubetech.com/images/up-arrow.svg"/></a>
# <div class="position-fixed main-mega-menu bg-white w-100 start-0 end-0 mx-auto pe-lg-4">
# <div class="d-lg-flex menu-nav-tabs">
# <ul class="d-flex flex-column list-unstyled nav-tabs-button border-end">
# <li class="sub-menu d-flex justify-content-around align-items-center cursor-pointer label-color-1 border-bottom active" onmouseover="openCity(event, 'jodhpur')">
# ...

# %%
url="https://www.wscubetech.com/"
r=requests.get(url)
soup =BeautifulSoup(r.text,"lxml")
tag=soup.div
print(tag.attrs)
# Out:
# {'class': ['container-fluid']}

# %%
url="https://www.wscubetech.com/"
r=requests.get(url)
soup =BeautifulSoup(r.text,"lxml")
tag=soup.header#header 2 attributes role is key ,banner it is also key
print(tag.attrs)
# Out:
# {'class': ['home-navbar', 'header-section', 'bg-white', 'position-sticky', 'top-0']}

# %%
url="https://www.wscubetech.com/"
r=requests.get(url)
soup =BeautifulSoup(r.text,"lxml")
tag=soup.header#header 2 attributes role is key ,banner it is also key
atb=(tag.attrs)
print(atb["class"])
# Out:
# ['home-navbar', 'header-section', 'bg-white', 'position-sticky', 'top-0']

# %% [markdown]
# **Navigable strings**

# %%
url="https://webscraper.io/test-sites/e-commerce/allinone"
r=requests.get(url)
soup =BeautifulSoup(r.text,"lxml")
tag=soup.div.p
print(tag)
# Out:
# <p>Web Scraper</p>

# %%
url="https://webscraper.io/test-sites/e-commerce/allinone"
r=requests.get(url)
soup =BeautifulSoup(r.text,"lxml")
tag=soup.header.div.a.button.span
print(tag)
# Out:
# <span class="visually-hidden">Toggle navigation</span>

# %% [markdown]
# **Comments in HTML**

# %% [markdown]
# **BeautifulSoup**
#
# * find()

# %%
url="https://webscraper.io/test-sites/e-commerce/allinone/computers/tablets"
r=requests.get(url)
soup=BeautifulSoup(r.text,"lxml")
##print(Soup.find("div"))
print(Soup.find("h4",{"class":"pull-right price"}))
# Out:
# None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "http://www.hubertiming.com/results/2017GPTR10K"
html = urlopen(url)

# %%
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
bs4.BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6786b081c27c> in <cell line: 1>()
# ----> 1 bs4.BeautifulSoup
#
# NameError: name 'bs4' is not defined

# %%
# Get the title
title = soup.title
print(title)
# Out:
# <title>Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!</title>

# %%
# Print out the text
text = soup.get_text()
#print(soup.text)

# %%
soup.find_all('a')
# Out:
# [<a href="mailto:timing@hubertiming.com">timing@hubertiming.com</a>,
#  <a href="https://www.hubertiming.com">Huber Timing Home</a>,
#  <a class="btn btn-primary btn-lg" href="/results/2017GPTR" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> 5K Individual</a>,
#  <a class="btn btn-primary btn-lg" href="/results/team/2017GPTR" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-users"></i> 5K Team</a>,
#  <a class="btn btn-primary btn-lg" href="/results/team/2017GPTR10K" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-users"></i> 10K Team</a>,
#  <a class="btn btn-primary btn-lg" href="/results/summary/2017GPTR10K" role="button" style="margin: 0px 0px 5px 5px"><i class="fa fa-stream"></i> Summary</a>,
#  <a id="individual" name="individual"></a>,
#  <a data-url="/results/2017GPTR10K" href="#tabs-1" id="rootTab" style="font-size: 18px">10K Results</a>,
# ...

# %%
all_links = soup.find_all("a")
for link in all_links:
    print(link.get("href"))
# Out:
# mailto:timing@hubertiming.com
# https://www.hubertiming.com
# /results/2017GPTR
# /results/team/2017GPTR
# /results/team/2017GPTR10K
# /results/summary/2017GPTR10K
# None
# #tabs-1
# https://www.hubertiming.com/
# https://facebook.com/hubertiming/
# None

# %%
# Print the first 10 rows for sanity check
rows = soup.find_all('tr')
print(rows[:10])
# Out:
# [<tr colspan="2">
# <b>10K:</b>
# </tr>, <tr>
# <td>Finishers:</td>
# <td>577</td>
# </tr>, <tr>
# <td>Male:</td>
# <td>414</td>
# </tr>, <tr>
# <td>Female:</td>
# <td>163</td>
# </tr>, <tr class="header">
# <th>Place</th>
# <th>Bib</th>
# <th>Name</th>
# <th>Gender</th>
# <th>City</th>
# <th>State</th>
# <th>Time</th>
# <th>Gun Time</th>
# <th>Team</th>
# </tr>, <tr data-bib="814">
# <td>1</td>
# <td>814</td>
# <td>
#
#                     JARED WILSON
#
#                 </td>
# <td>M</td>
# <td>TIGARD</td>
# <td>OR</td>
# <td>36:21</td>
# <td>36:24</td>
# <td></td>
# </tr>, <tr data-bib="573">
# <td>2</td>
# <td>573</td>
# <td>
#
#                     NATHAN A SUSTERSIC
#
#                 </td>
# <td>M</td>
# <td>PORTLAND</td>
# <td>OR</td>
# <td>36:42</td>
# <td>36:45</td>
# <td>
# <img class="lazy teamThumbs" data-src="/teamLogoThumbnail/logo?teamName=INTEL%20TEAM%20F&amp;raceId=1251&amp;state=OR"/>
#                             INTEL TEAM F
#                         </td>
# ...

# %%
for row in rows:
    row_td = row.find_all('td')
print(row_td)
type(row_td)
# Out:
# [<td>577</td>, <td>443</td>, <td>
#
#                     LIBBY B MITCHELL
#
#                 </td>, <td>F</td>, <td>HILLSBORO</td>, <td>OR</td>, <td>1:41:18</td>, <td>1:42:10</td>, <td></td>]
# bs4.element.ResultSet

# %%
str_cells = str(row_td)
cleantext = BeautifulSoup(str_cells, "lxml").get_text()
print(cleantext)
# Out:
# [577, 443,
#
#                     LIBBY B MITCHELL
#
#                 , F, HILLSBORO, OR, 1:41:18, 1:42:10, ]

# %%
import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)
print(clean2)
type(clean2)
# Out:
# [577, 443,
#
#                     LIBBY B MITCHELL
#
#                 , F, HILLSBORO, OR, 1:41:18, 1:42:10, ]
# str

# %%
df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0                                                 []
# 1                                  [Finishers:, 577]
# 2                                       [Male:, 414]
# 3                                     [Female:, 163]
# 4                                                 []
# 5  [1, 814, \r\n\r\n                    JARED WIL...
# 6  [2, 573, \r\n\r\n                    NATHAN A ...
# 7  [3, 687, \r\n\r\n                    FRANCISCO...
# 8  [4, 623, \r\n\r\n                    PAUL MORR...
# 9  [5, 569, \r\n\r\n                    DEREK G O...

# %%
df1 = df[0].str.split(',', expand=True)
df1.head(10)
# Out:
#              0      1                                                  2  \
# 0           []   None                                               None
# 1  [Finishers:   577]                                               None
# 2       [Male:   414]                                               None
# 3     [Female:   163]                                               None
# 4           []   None                                               None
# 5           [1    814   \r\n\r\n                    JARED WILSON\r\n\...
# 6           [2    573   \r\n\r\n                    NATHAN A SUSTERSI...
# 7           [3    687   \r\n\r\n                    FRANCISCO MAYA\r\...
# 8           [4    623   \r\n\r\n                    PAUL MORROW\r\n\r...
# 9           [5    569   \r\n\r\n                    DEREK G OSBORNE\r...
#
#       3           4     5       6       7  \
# 0  None        None  None    None    None
# 1  None        None  None    None    None
# ...

# %%
df1[0] = df1[0].str.strip('[')
df1.head(10)
# Out:
#             0      1                                                  2     3  \
# 0           ]   None                                               None  None
# 1  Finishers:   577]                                               None  None
# 2       Male:   414]                                               None  None
# 3     Female:   163]                                               None  None
# 4           ]   None                                               None  None
# 5           1    814   \r\n\r\n                    JARED WILSON\r\n\...     M
# 6           2    573   \r\n\r\n                    NATHAN A SUSTERSI...     M
# 7           3    687   \r\n\r\n                    FRANCISCO MAYA\r\...     M
# 8           4    623   \r\n\r\n                    PAUL MORROW\r\n\r...     M
# 9           5    569   \r\n\r\n                    DEREK G OSBORNE\r...     M
#
#             4     5       6       7  \
# 0        None  None    None    None
# ...

# %%
col_labels = soup.find_all('th')

# %%
all_header = []
col_str = str(col_labels)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)
print(all_header)
# Out:
# ['[Place, Bib, Name, Gender, City, State, Time, Gun Time, Team]']

# %%
df2 = pd.DataFrame(all_header)
df2.head()
# Out:
#                                                    0
# 0  [Place, Bib, Name, Gender, City, State, Time, ...

# %% [markdown]
# # New Section
